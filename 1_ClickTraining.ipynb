# %%
#@markdown ## ♍ **Upload Photo**
#@markdown - Upload foto dengan resolusi maksimal 2000 pixel.
#@markdown - Untuk hasil training yang sempurna upload minimum 30 foto dengan aspek rasio 1:1 Closeup | 8:10 Half Body | 4:6 Full Body
#@markdown - Ubah nama file dibawah ini tanpa menggunakan spasi.

import os
from google.colab import files
import shutil

train_data_dir = "/content/LoRA/train_data"
os.makedirs(train_data_dir, exist_ok=True)
upload_folder = '/content/LoRA/train_data'

if os.path.isdir(upload_folder):
    shutil.rmtree(upload_folder)
os.mkdir(upload_folder)

############################################################

uploaded = files.upload()
for filename in uploaded.keys():
  dst_path = os.path.join(upload_folder, filename)
  print(f'move {filename} to {dst_path}')
  shutil.move(filename, dst_path)

############################################################

def main():

    upload_folder = "/content/LoRA/train_data"
    UBAH_NAMA = "anang" #@param {type:'string'}

    for count, filename in enumerate(os.listdir(upload_folder)):
        dst =f"{UBAH_NAMA}{str(count)}.jpg"
        src =f"{upload_folder}/{filename}"
        dst =f"{upload_folder}/{dst}"
        os.rename(src, dst)

if __name__ == '__main__':
    main()

############################################################

from IPython.display import clear_output
clear_output()
print("✅ Upload gambar sukses!")

# %%
#@markdown ## ♍ **Start SDXL LoRa Training**
#@markdown - Pastikan memilih T4 untuk hardware accelerator pada runtime.
#@markdown - Hubungkan ke GoogleDrive jika ingin menyimpan LoRA di akun gDrive

import os
import zipfile
import shutil
import time
import requests
import torch
from subprocess import getoutput
from IPython.utils import capture
from google.colab import drive

# %store -r

# root_dir
root_dir          = "/content"
drive_dir         = os.path.join(root_dir, "drive/MyDrive")
deps_dir          = os.path.join(root_dir, "deps")
repo_dir          = os.path.join(root_dir, "kohya-trainer")
training_dir      = os.path.join(root_dir, "LoRA")
pretrained_model  = os.path.join(root_dir, "pretrained_model")
vae_dir           = os.path.join(root_dir, "vae")
lora_dir          = os.path.join(root_dir, "network_weight")
repositories_dir  = os.path.join(root_dir, "repositories")
config_dir        = os.path.join(training_dir, "config")
tools_dir         = os.path.join(repo_dir, "tools")
finetune_dir      = os.path.join(repo_dir, "finetune")
accelerate_config = os.path.join(repo_dir, "accelerate_config/config.yaml")

for store in ["root_dir", "repo_dir", "training_dir", "pretrained_model", "vae_dir", "repositories_dir", "accelerate_config", "tools_dir", "finetune_dir", "config_dir"]:
    with capture.capture_output() as cap:
        # %store {store}
        del cap

repo_dict = {
    "qaneel/kohya-trainer (forked repo, stable, optimized for colab use)" : "https://github.com/qaneel/kohya-trainer",
    "kohya-ss/sd-scripts (original repo, latest update)"                    : "https://github.com/kohya-ss/sd-scripts",
}

repository        = "qaneel/kohya-trainer (forked repo, stable, optimized for colab use)"
repo_url          = repo_dict[repository]
branch            = "main"
output_to_drive   = False # @param {type: "boolean"}

def clone_repo(url, dir, branch):
    if not os.path.exists(dir):
       # !git clone -b {branch} {url} {dir}

def mount_drive(dir):
    output_dir      = os.path.join(training_dir, "output")

    if output_to_drive:
        if not os.path.exists(drive_dir):
            drive.mount(os.path.dirname(drive_dir))
        output_dir  = os.path.join(drive_dir, "kohya-trainer/output")

    return output_dir

def setup_directories():
    global output_dir

    output_dir      = mount_drive(drive_dir)

    for dir in [training_dir, config_dir, pretrained_model, vae_dir, repositories_dir, output_dir]:
        os.makedirs(dir, exist_ok=True)

def pastebin_reader(id):
    if "pastebin.com" in id:
        url = id
        if 'raw' not in url:
                url = url.replace('pastebin.com', 'pastebin.com/raw')
    else:
        url = "https://pastebin.com/raw/" + id
    response = requests.get(url)
    response.raise_for_status()
    lines = response.text.split('\n')
    return lines

def install_repository():
    global infinite_image_browser_dir, voldy, discordia_archivum_dir

    _, voldy = pastebin_reader("kq6ZmHFU")[:2]

    infinite_image_browser_url  = f"https://github.com/zanllp/{voldy}-infinite-image-browsing.git"
    infinite_image_browser_dir  = os.path.join(repositories_dir, f"infinite-image-browsing")
    infinite_image_browser_deps = os.path.join(infinite_image_browser_dir, "requirements.txt")

    discordia_archivum_url = "https://github.com/Linaqruf/discordia-archivum"
    discordia_archivum_dir = os.path.join(repositories_dir, "discordia-archivum")
    discordia_archivum_deps = os.path.join(discordia_archivum_dir, "requirements.txt")

    clone_repo(infinite_image_browser_url, infinite_image_browser_dir, "main")
    clone_repo(discordia_archivum_url, discordia_archivum_dir, "main")

    # !pip install -q --upgrade -r {infinite_image_browser_deps}
    # !pip install python-dotenv
    # !pip install -q --upgrade -r {discordia_archivum_deps}

def install_dependencies():
    requirements_file = os.path.join(repo_dir, "requirements.txt")
    model_util        = os.path.join(repo_dir, "library/model_util.py")
    gpu_info          = getoutput('nvidia-smi')
    t4_xformers_wheel = "https://github.com/Linaqruf/colab-xformers/releases/download/0.0.20/xformers-0.0.20+1d635e1.d20230519-cp310-cp310-linux_x86_64.whl"

    # !apt install aria2 lz4
    # !wget https://github.com/camenduru/gperftools/releases/download/v1.0/libtcmalloc_minimal.so.4 -O /content/libtcmalloc_minimal.so.4
    # !pip install -q --upgrade -r {requirements_file}

    # !pip install -q xformers==0.0.22.post7

    from accelerate.utils import write_basic_config

    if not os.path.exists(accelerate_config):
        write_basic_config(save_location=accelerate_config)

def prepare_environment():
    os.environ["LD_PRELOAD"] = "/content/libtcmalloc_minimal.so.4"
    os.environ["TF_CPP_MIN_LOG_LEVEL"] = "3"
    os.environ["SAFETENSORS_FAST_GPU"] = "1"
    os.environ["PYTHONWARNINGS"] = "ignore"

def main():
    os.chdir(root_dir)
    clone_repo(repo_url, repo_dir, branch)
    os.chdir(repo_dir)
    setup_directories()
    install_repository()
    install_dependencies()
    prepare_environment()

main()

from IPython.display import clear_output
clear_output()
##################################################################

import os
import re
import json
import glob
import gdown
import requests
import subprocess
from IPython.utils import capture
from urllib.parse import urlparse, unquote
from pathlib import Path
from huggingface_hub import HfFileSystem
from huggingface_hub.utils import validate_repo_id, HfHubHTTPError

# %store -r

os.chdir(root_dir)



HUGGINGFACE_TOKEN     = "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"
LOAD_DIFFUSERS_MODEL  = True
SDXL_MODEL_URL        = "stabilityai/stable-diffusion-xl-base-1.0"
SDXL_VAE_URL          = "Original VAE"

MODEL_URLS = {
    "gsdf/CounterfeitXL"        : "https://huggingface.co/gsdf/CounterfeitXL/resolve/main/CounterfeitXL_%CE%B2.safetensors",
    "Linaqruf/animagine-xl"   : "https://huggingface.co/Linaqruf/animagine-xl/resolve/main/animagine-xl.safetensors",
    "stabilityai/stable-diffusion-xl-base-1.0" : "https://huggingface.co/stabilityai/stable-diffusion-xl-base-1.0/resolve/main/sd_xl_base_1.0.safetensors",
}
VAE_URLS = {
    "None"                    : "",
    "Original VAE"           : "https://huggingface.co/stabilityai/sdxl-vae/resolve/main/sdxl_vae.safetensors",
    "FP16 VAE"           : "https://huggingface.co/madebyollin/sdxl-vae-fp16-fix/resolve/main/sdxl_vae.safetensors"
}

SDXL_MODEL_URL = MODEL_URLS.get(SDXL_MODEL_URL, SDXL_MODEL_URL)
SDXL_VAE_URL = VAE_URLS.get(SDXL_VAE_URL, SDXL_VAE_URL)

def get_filename(url):
    if any(url.endswith(ext) for ext in [".ckpt", ".safetensors", ".pt", ".pth"]):
        return os.path.basename(url)

    response = requests.get(url, stream=True)
    response.raise_for_status()

    if 'content-disposition' in response.headers:
        filename = re.findall('filename="?([^"]+)"?', response.headers['content-disposition'])[0]
    else:
        filename = unquote(os.path.basename(urlparse(url).path))

    return filename

def aria2_download(dir, filename, url):
    user_header = f"Authorization: Bearer {HUGGINGFACE_TOKEN}"
    aria2_args = [
        "aria2c",
        "--console-log-level=error",
        "--summary-interval=10",
        f"--header={user_header}" if "huggingface.co" in url else "",
        "--continue=true",
        "--max-connection-per-server=16",
        "--min-split-size=1M",
        "--split=16",
        f"--dir={dir}",
        f"--out={filename}",
        url
    ]
    subprocess.run(aria2_args)

def download(url, dst):
    print(f"Starting downloading from {url}")
    filename = get_filename(url)
    filepath = os.path.join(dst, filename)

    if "drive.google.com" in url:
        gdown.download(url, filepath, quiet=False)
    else:
        if "huggingface.co" in url and "/blob/" in url:
            url = url.replace("/blob/", "/resolve/")
        aria2_download(dst, filename, url)

    print(f"Download finished: {filepath}")
    return filepath

def all_folders_present(base_model_url, sub_folders):
    fs = HfFileSystem()
    existing_folders = set(fs.ls(base_model_url, detail=False))

    for folder in sub_folders:
        full_folder_path = f"{base_model_url}/{folder}"
        if full_folder_path not in existing_folders:
            return False
    return True

def get_total_ram_gb():
    with open('/proc/meminfo', 'r') as f:
        for line in f.readlines():
            if "MemTotal" in line:
                return int(line.split()[1]) / (1024**2)  # Convert to GB

def get_gpu_name():
    try:
        return subprocess.check_output("nvidia-smi --query-gpu=name --format=csv,noheader,nounits", shell=True).decode('ascii').strip()
    except:
        return None

def main():
    global model_path, vae_path, LOAD_DIFFUSERS_MODEL

    model_path, vae_path = None, None

    required_sub_folders = [
        'scheduler',
        'text_encoder',
        'text_encoder_2',
        'tokenizer',
        'tokenizer_2',
        'unet',
        'vae',
    ]

    download_targets = {
        "model": (SDXL_MODEL_URL, pretrained_model),
        "vae": (SDXL_VAE_URL, vae_dir),
    }

    total_ram = get_total_ram_gb()
    gpu_name = get_gpu_name()

    # Check hardware constraints
    if total_ram < 13 and gpu_name in ["Tesla T4", "Tesla V100"]:
        print("Attempt to load diffusers model instead due to hardware constraints.")
        if not LOAD_DIFFUSERS_MODEL:
            LOAD_DIFFUSERS_MODEL = True

    for target, (url, dst) in download_targets.items():
        if url and not url.startswith(f"PASTE {target.upper()} URL OR GDRIVE PATH HERE"):
            if target == "model" and LOAD_DIFFUSERS_MODEL:
                # Code for checking and handling diffusers model
                if 'huggingface.co' in url:
                    match = re.search(r'huggingface\.co/([^/]+)/([^/]+)', SDXL_MODEL_URL)
                    if match:
                        username = match.group(1)
                        model_name = match.group(2)
                        url = f"{username}/{model_name}"
                if all_folders_present(url, required_sub_folders):
                    print(f"Diffusers model is loaded : {url}")
                    model_path = url
                else:
                    print("Repository doesn't exist or no diffusers model detected.")
                    filepath = download(url, dst)  # Continue with the regular download
                    model_path = filepath
            else:
                filepath = download(url, dst)

                if target == "model":
                    model_path = filepath
                elif target == "vae":
                    vae_path = filepath

            print()

    if model_path:
        print(f"Selected model: {model_path}")

    if vae_path:
        print(f"Selected VAE: {vae_path}")

main()
###############################################

import os
import random
import concurrent.futures
from tqdm import tqdm
from PIL import Image

# %store -r

os.chdir(root_dir)

test = os.listdir(train_data_dir)
convert = False
random_color = False
recursive = False

batch_size = 32
supported_types = [
    ".png",
    ".jpg",
    ".JPG",
    ".jpeg",
    ".webp",
    ".bmp",
    ".caption",
    ".npz",
    ".txt",
    ".json",
]

background_colors = [
    (255, 255, 255),
    (0, 0, 0),
    (255, 0, 0),
    (0, 255, 0),
    (0, 0, 255),
    (255, 255, 0),
    (255, 0, 255),
    (0, 255, 255),
]

def clean_directory(directory):
    for item in os.listdir(directory):
        file_path = os.path.join(directory, item)
        if os.path.isfile(file_path):
            file_ext = os.path.splitext(item)[1]
            if file_ext not in supported_types:
                print(f"Deleting file {item} from {directory}")
                os.remove(file_path)
        elif os.path.isdir(file_path) and recursive:
            clean_directory(file_path)

def process_image(image_path):
    img = Image.open(image_path)
    img_dir, image_name = os.path.split(image_path)

    if img.mode in ("RGBA", "LA"):
        if random_color:
            background_color = random.choice(background_colors)
        else:
            background_color = (255, 255, 255)
        bg = Image.new("RGB", img.size, background_color)
        bg.paste(img, mask=img.split()[-1])

        if image_name.endswith(".webp"):
            bg = bg.convert("RGB")
            new_image_path = os.path.join(img_dir, image_name.replace(".webp", ".jpg"))
            bg.save(new_image_path, "JPEG")
            os.remove(image_path)
            print(f" Converted image: {image_name} to {os.path.basename(new_image_path)}")
        else:
            bg.save(image_path, "PNG")
            print(f" Converted image: {image_name}")
    else:
        if image_name.endswith(".webp"):
            new_image_path = os.path.join(img_dir, image_name.replace(".webp", ".jpg"))
            img.save(new_image_path, "JPEG")
            os.remove(image_path)
            print(f" Converted image: {image_name} to {os.path.basename(new_image_path)}")
        else:
            img.save(image_path, "PNG")

def find_images(directory):
    images = []
    for root, _, files in os.walk(directory):
        for file in files:
            if file.endswith(".png") or file.endswith(".webp"):
                images.append(os.path.join(root, file))
    return images

clean_directory(train_data_dir)
images = find_images(train_data_dir)
num_batches = len(images) // batch_size + 1

if convert:
    with concurrent.futures.ThreadPoolExecutor() as executor:
        for i in tqdm(range(num_batches)):
            start = i * batch_size
            end = start + batch_size
            batch = images[start:end]
            executor.map(process_image, batch)

    print("All images have been converted")
###############################################

import os

os.chdir(finetune_dir)

beam_search = True
min_length = 5
max_length = 75

config = {
    "_train_data_dir"   : train_data_dir,
    "batch_size"        : 8,
    "beam_search"       : beam_search,
    "min_length"        : min_length,
    "max_length"        : max_length,
    "debug"             : True,
    "caption_extension" : ".caption",
    "max_data_loader_n_workers" : 2,
    "recursive"         : True
}

args = ""
for k, v in config.items():
    if k.startswith("_"):
        args += f'"{v}" '
    elif isinstance(v, str):
        args += f'--{k}="{v}" '
    elif isinstance(v, bool) and v:
        args += f"--{k} "
    elif isinstance(v, float) and not isinstance(v, bool):
        args += f"--{k}={v} "
    elif isinstance(v, int) and not isinstance(v, bool):
        args += f"--{k}={v} "

final_args = f"python make_captions.py {args}"

os.chdir(finetune_dir)
# !{final_args}
###############################################

import os
# %store -r

os.chdir(finetune_dir)


model = "SmilingWolf/wd-v1-4-moat-tagger-v2"
undesired_tags = ""
general_threshold = 0.35
character_threshold = 0.7

config = {
    "_train_data_dir"           : train_data_dir,
    "batch_size"                : 8,
    "repo_id"                   : model,
    "recursive"                 : True,
    "remove_underscore"         : True,
    "general_threshold"         : general_threshold,
    "character_threshold"       : character_threshold,
    "caption_extension"         : ".txt",
    "max_data_loader_n_workers" : 2,
    "debug"                     : True,
    "undesired_tags"            : undesired_tags
}

args = ""
for k, v in config.items():
    if k.startswith("_"):
        args += f'"{v}" '
    elif isinstance(v, str):
        args += f'--{k}="{v}" '
    elif isinstance(v, bool) and v:
        args += f"--{k} "
    elif isinstance(v, float) and not isinstance(v, bool):
        args += f"--{k}={v} "
    elif isinstance(v, int) and not isinstance(v, bool):
        args += f"--{k}={v} "

final_args = f"python tag_images_by_wd14_tagger.py {args}"

os.chdir(finetune_dir)
# !{final_args}
###############################################

import os

# %store -r

os.chdir(root_dir)

extension   = ".txt"
custom_tag  = "simple background, white background, grey background"
sub_folder  = ""
append      = False
remove_tag  = True
recursive   = False

if sub_folder == "":
    image_dir = train_data_dir
elif sub_folder == "--all":
    image_dir = train_data_dir
    recursive = True
elif sub_folder.startswith("/content"):
    image_dir = sub_folder
else:
    image_dir = os.path.join(train_data_dir, sub_folder)
    os.makedirs(image_dir, exist_ok=True)

def read_file(filename):
    with open(filename, "r") as f:
        contents = f.read()
    return contents

def write_file(filename, contents):
    with open(filename, "w") as f:
        f.write(contents)

def process_tags(filename, custom_tag, append, remove_tag):
    contents = read_file(filename)
    tags = [tag.strip() for tag in contents.split(',')]
    custom_tags = [tag.strip() for tag in custom_tag.split(',')]

    for custom_tag in custom_tags:
        custom_tag = custom_tag.replace("_", " ")
        if remove_tag:
            while custom_tag in tags:
                tags.remove(custom_tag)
        else:
            if custom_tag not in tags:
                if append:
                    tags.append(custom_tag)
                else:
                    tags.insert(0, custom_tag)

    contents = ', '.join(tags)
    write_file(filename, contents)

def process_directory(image_dir, tag, append, remove_tag, recursive):
    for filename in os.listdir(image_dir):
        file_path = os.path.join(image_dir, filename)

        if os.path.isdir(file_path) and recursive:
            process_directory(file_path, tag, append, remove_tag, recursive)
        elif filename.endswith(extension):
            process_tags(file_path, tag, append, remove_tag)

tag = custom_tag

if not any(
    [filename.endswith(extension) for filename in os.listdir(image_dir)]
):
    for filename in os.listdir(image_dir):
        if filename.endswith((".png", ".jpg", ".jpeg", ".webp", ".bmp")):
            open(
                os.path.join(image_dir, filename.split(".")[0] + extension),
                "w",
            ).close()

if custom_tag:
    process_directory(image_dir, tag, append, remove_tag, recursive)
####################################################
# %store -r

bucketing_json    = os.path.join(training_dir, "meta_lat.json")
metadata_json     = os.path.join(training_dir, "meta_clean.json")
bucket_resolution = 1024
mixed_precision   = "no"
skip_existing     = False
flip_aug          = False
clean_caption     = False
recursive         = True

metadata_config = {
    "_train_data_dir": train_data_dir,
    "_out_json": metadata_json,
    "recursive": recursive,
    "full_path": recursive,
    "clean_caption": clean_caption
}

bucketing_config = {
    "_train_data_dir": train_data_dir,
    "_in_json": metadata_json,
    "_out_json": bucketing_json,
    "_model_name_or_path": vae_path if vae_path else model_path,
    "recursive": recursive,
    "full_path": recursive,
    "flip_aug": flip_aug,
    "skip_existing": skip_existing,
    "batch_size": 4,
    "max_data_loader_n_workers": 2,
    "max_resolution": f"{bucket_resolution}, {bucket_resolution}",
    "mixed_precision": mixed_precision,
}

def generate_args(config):
    args = ""
    for k, v in config.items():
        if k.startswith("_"):
            args += f'"{v}" '
        elif isinstance(v, str):
            args += f'--{k}="{v}" '
        elif isinstance(v, bool) and v:
            args += f"--{k} "
        elif isinstance(v, float) and not isinstance(v, bool):
            args += f"--{k}={v} "
        elif isinstance(v, int) and not isinstance(v, bool):
            args += f"--{k}={v} "
    return args.strip()

merge_metadata_args = generate_args(metadata_config)
prepare_buckets_args = generate_args(bucketing_config)

merge_metadata_command = f"python merge_all_to_metadata.py {merge_metadata_args}"
prepare_buckets_command = f"python prepare_buckets_latents.py {prepare_buckets_args}"

os.chdir(finetune_dir)
# !{merge_metadata_command}
time.sleep(1)
# !{prepare_buckets_command}

#########################################################
import toml

network_category = "LoRA_LierLa"
network_args    = ""
network_dim     = 32
network_alpha   = 16
conv_dim        = 32
conv_alpha      = 16
unit = 4

if isinstance(network_args, str):
    network_args = network_args.strip()
    if network_args.startswith('[') and network_args.endswith(']'):
        try:
            network_args = ast.literal_eval(network_args)
        except (SyntaxError, ValueError) as e:
            print(f"Error parsing network_args: {e}\n")
            network_args = []
    elif len(network_args) > 0:
        print(f"WARNING! '{network_args}' is not a valid list! Put args like this: [\"args=1\", \"args=2\"]\n")
        network_args = []
    else:
        network_args = []
else:
    network_args = []

network_config = {
    "LoRA_LierLa": {
        "module": "networks.lora",
        "args"  : []
    },
    "LoRA_C3Lier": {
        "module": "networks.lora",
        "args"  : [
            f"conv_dim={conv_dim}",
            f"conv_alpha={conv_alpha}"
        ]
    },
    "DyLoRA_LierLa": {
        "module": "networks.dylora",
        "args"  : [
            f"unit={unit}"
        ]
    },
    "DyLoRA_C3Lier": {
        "module": "networks.dylora",
        "args"  : [
            f"conv_dim={conv_dim}",
            f"conv_alpha={conv_alpha}",
            f"unit={unit}"
        ]
    },
    "LoCon": {
        "module": "lycoris.kohya",
        "args"  : [
            f"algo=locon",
            f"conv_dim={conv_dim}",
            f"conv_alpha={conv_alpha}"
        ]
    },
    "LoHa": {
        "module": "lycoris.kohya",
        "args"  : [
            f"algo=loha",
            f"conv_dim={conv_dim}",
            f"conv_alpha={conv_alpha}"
        ]
    },
    "IA3": {
        "module": "lycoris.kohya",
        "args"  : [
            f"algo=ia3",
            f"conv_dim={conv_dim}",
            f"conv_alpha={conv_alpha}"
        ]
    },
    "LoKR": {
        "module": "lycoris.kohya",
        "args"  : [
            f"algo=lokr",
            f"conv_dim={conv_dim}",
            f"conv_alpha={conv_alpha}"
        ]
    },
    "DyLoRA_Lycoris": {
        "module": "lycoris.kohya",
        "args"  : [
            f"algo=dylora",
            f"conv_dim={conv_dim}",
            f"conv_alpha={conv_alpha}"
        ]
    }
}

network_module = network_config[network_category]["module"]
network_args.extend(network_config[network_category]["args"])

lora_config = {
    "additional_network_arguments": {
        "no_metadata"                     : False,
        "network_module"                  : network_module,
        "network_dim"                     : network_dim,
        "network_alpha"                   : network_alpha,
        "network_args"                    : network_args,
        "network_train_unet_only"         : True,
        "training_comment"                : None,
    },
}

print(toml.dumps(lora_config))

#################################################################################
#Optimizer Config
import toml
import ast

optimizer_type = "AdaFactor"
optimizer_args = "[ \"scale_parameter=False\", \"relative_step=False\", \"warmup_init=False\" ]"
learning_rate = 1e-4
lr_scheduler = "constant_with_warmup"
lr_warmup_steps = 100
lr_scheduler_num = 0

if isinstance(optimizer_args, str):
    optimizer_args = optimizer_args.strip()
    if optimizer_args.startswith('[') and optimizer_args.endswith(']'):
        try:
            optimizer_args = ast.literal_eval(optimizer_args)
        except (SyntaxError, ValueError) as e:
            print(f"Error parsing optimizer_args: {e}\n")
            optimizer_args = []
    elif len(optimizer_args) > 0:
        print(f"WARNING! '{optimizer_args}' is not a valid list! Put args like this: [\"args=1\", \"args=2\"]\n")
        optimizer_args = []
    else:
        optimizer_args = []
else:
    optimizer_args = []

optimizer_config = {
    "optimizer_arguments": {
        "optimizer_type"          : optimizer_type,
        "learning_rate"           : learning_rate,
        "max_grad_norm"           : 0,
        "optimizer_args"          : optimizer_args,
        "lr_scheduler"            : lr_scheduler,
        "lr_warmup_steps"         : lr_warmup_steps,
        "lr_scheduler_num_cycles" : lr_scheduler_num if lr_scheduler == "cosine_with_restarts" else None,
        "lr_scheduler_power"      : lr_scheduler_num if lr_scheduler == "polynomial" else None,
        "lr_scheduler_type"       : None,
        "lr_scheduler_args"       : None,
    },
}

print(toml.dumps(optimizer_config))

from IPython.display import clear_output
clear_output()
#####################################################

import toml
import os
from subprocess import getoutput

# %store -r

project_name                = "sdxl_lora"  # @param {type:"string"}
wandb_api_key               = ""
in_json                     = "/content/LoRA/meta_lat.json"
gradient_checkpointing      = True
no_half_vae                 = True
cache_text_encoder_outputs  = False
min_timestep                = 0
max_timestep                = 1000
num_repeats                 = 2  # @param {type:"number"}
resolution                  = 1024
keep_tokens                 = 0
num_epochs                  = 10  # @param {type:"number"}
train_batch_size            = 4  # @param {type:"number"}
mixed_precision             = "fp16"
seed                        = -1
optimization                = "scaled dot-product attention"
save_precision              = "fp16"
save_every_n_epochs         = 1
enable_sample               = False
sampler                     = "euler_a"
positive_prompt             = ""
negative_prompt             = ""
quality_prompt              = "NovelAI"
if quality_prompt          == "NovelAI":
    positive_prompt         = "masterpiece, best quality, "
    negative_prompt         = "lowres, bad anatomy, bad hands, text, error, missing fingers, extra digit, fewer digits, cropped, worst quality, low quality, normal quality, jpeg artifacts, signature, watermark, username, blurry, "
if quality_prompt          == "AbyssOrangeMix":
    positive_prompt         = "masterpiece, best quality, "
    negative_prompt         = "(worst quality, low quality:1.4), "
if quality_prompt          == "Stable Diffusion XL":
    negative_prompt         = "3d render, smooth, plastic, blurry, grainy, low-resolution, deep-fried, oversaturated"
custom_prompt               = "face focus, cute, 1girl, green hair, sweater, looking at viewer, upper body, beanie, outdoors, night, turtleneck"

prompt_from_caption         = "none"
if prompt_from_caption     != "none":
    custom_prompt           = ""
num_prompt                  = 2
logging_dir                 = os.path.join(training_dir, "logs")
lowram                      = int(next(line.split()[1] for line in open('/proc/meminfo') if "MemTotal" in line)) / (1024**2) < 15

os.chdir(repo_dir)

prompt_config = {
    "prompt": {
        "negative_prompt" : negative_prompt,
        "width"           : resolution,
        "height"          : resolution,
        "scale"           : 12,
        "sample_steps"    : 28,
        "subset"          : [],
    }
}

train_config = {
    "sdxl_arguments": {
        "cache_text_encoder_outputs" : cache_text_encoder_outputs,
        "no_half_vae"                : True,
        "min_timestep"               : min_timestep,
        "max_timestep"               : max_timestep,
        "shuffle_caption"            : True if not cache_text_encoder_outputs else False,
        "lowram"                     : lowram
    },
    "model_arguments": {
        "pretrained_model_name_or_path" : model_path,
        "vae"                           : vae_path,
    },
    "dataset_arguments": {
        "debug_dataset"                 : False,
        "in_json"                       : in_json,
        "train_data_dir"                : train_data_dir,
        "dataset_repeats"               : num_repeats,
        "keep_tokens"                   : keep_tokens,
        "resolution"                    : str(resolution) + ',' + str(resolution),
        "color_aug"                     : False,
        "face_crop_aug_range"           : None,
        "token_warmup_min"              : 1,
        "token_warmup_step"             : 0,
    },
    "training_arguments": {
        "output_dir"                    : os.path.join(output_dir, project_name),
        "output_name"                   : project_name if project_name else "last",
        "save_precision"                : save_precision,
        "save_every_n_epochs"           : save_every_n_epochs,
        "save_n_epoch_ratio"            : None,
        "save_last_n_epochs"            : None,
        "resume"                        : None,
        "train_batch_size"              : train_batch_size,
        "max_token_length"              : 225,
        "mem_eff_attn"                  : False,
        "sdpa"                          : True if optimization == "scaled dot-product attention" else False,
        "xformers"                      : True if optimization == "xformers" else False,
        "max_train_epochs"              : num_epochs,
        "max_data_loader_n_workers"     : 8,
        "persistent_data_loader_workers": True,
        "seed"                          : seed if seed > 0 else None,
        "gradient_checkpointing"        : gradient_checkpointing,
        "gradient_accumulation_steps"   : 1,
        "mixed_precision"               : mixed_precision,
    },
    "logging_arguments": {
        "log_with"          : "wandb" if wandb_api_key else "tensorboard",
        "log_tracker_name"  : project_name if wandb_api_key and not project_name == "last" else None,
        "logging_dir"       : logging_dir,
        "log_prefix"        : project_name if not wandb_api_key else None,
    },
    "sample_prompt_arguments": {
        "sample_every_n_steps"    : None,
        "sample_every_n_epochs"   : save_every_n_epochs if enable_sample else None,
        "sample_sampler"          : sampler,
    },
    "saving_arguments": {
        "save_model_as": "safetensors"
    },
}

def write_file(filename, contents):
    with open(filename, "w") as f:
        f.write(contents)

def prompt_convert(enable_sample, num_prompt, train_data_dir, prompt_config, custom_prompt):
    if enable_sample:
        search_pattern = os.path.join(train_data_dir, '**/*' + prompt_from_caption)
        caption_files = glob.glob(search_pattern, recursive=True)

        if not caption_files:
            if not custom_prompt:
                custom_prompt = "masterpiece, best quality, 1girl, aqua eyes, baseball cap, blonde hair, closed mouth, earrings, green background, hat, hoop earrings, jewelry, looking at viewer, shirt, short hair, simple background, solo, upper body, yellow shirt"
            new_prompt_config = prompt_config.copy()
            new_prompt_config['prompt']['subset'] = [
                {"prompt": positive_prompt + custom_prompt if positive_prompt else custom_prompt}
            ]
        else:
            selected_files = random.sample(caption_files, min(num_prompt, len(caption_files)))

            prompts = []
            for file in selected_files:
                with open(file, 'r') as f:
                    prompts.append(f.read().strip())

            new_prompt_config = prompt_config.copy()
            new_prompt_config['prompt']['subset'] = []

            for prompt in prompts:
                new_prompt = {
                    "prompt": positive_prompt + prompt if positive_prompt else prompt,
                }
                new_prompt_config['prompt']['subset'].append(new_prompt)

        return new_prompt_config
    else:
        return prompt_config

def eliminate_none_variable(config):
    for key in config:
        if isinstance(config[key], dict):
            for sub_key in config[key]:
                if config[key][sub_key] == "":
                    config[key][sub_key] = None
        elif config[key] == "":
            config[key] = None

    return config

try:
    train_config.update(optimizer_config)
except NameError:
    raise NameError("'optimizer_config' dictionary is missing. Please run  '4.1. Optimizer Config' cell.")

try:
    train_config.update(lora_config)
except NameError:
    raise NameError("'lora_config' dictionary is missing. Please run  '4.1. LoRa: Low-Rank Adaptation Config' cell.")

advanced_training_warning = False
try:
    train_config.update(advanced_training_config)
except NameError:
    advanced_training_warning = True
    pass

prompt_config = prompt_convert(enable_sample, num_prompt, train_data_dir, prompt_config, custom_prompt)

config_path         = os.path.join(config_dir, "config_file.toml")
prompt_path         = os.path.join(config_dir, "sample_prompt.toml")

config_str          = toml.dumps(eliminate_none_variable(train_config))
prompt_str          = toml.dumps(eliminate_none_variable(prompt_config))

write_file(config_path, config_str)
write_file(prompt_path, prompt_str)

print(config_str)

if advanced_training_warning:
    import textwrap
    error_message = "WARNING: This is not an error message, but the [advanced_training_config] dictionary is missing. Please run the '4.2. Advanced Training Config' cell if you intend to use it, or continue to the next step."
    wrapped_message = textwrap.fill(error_message, width=80)
    print('\033[38;2;204;102;102m' + wrapped_message + '\033[0m\n')
    pass

print(prompt_str)

from IPython.display import clear_output
clear_output()
######################################################

import os
import toml

sample_prompt   = "/content/LoRA/config/sample_prompt.toml"
config_file     = "/content/LoRA/config/config_file.toml"

def read_file(filename):
    with open(filename, "r") as f:
        contents = f.read()
    return contents

def train(config):
    args = ""
    for k, v in config.items():
        if k.startswith("_"):
            args += f'"{v}" '
        elif isinstance(v, str):
            args += f'--{k}="{v}" '
        elif isinstance(v, bool) and v:
            args += f"--{k} "
        elif isinstance(v, float) and not isinstance(v, bool):
            args += f"--{k}={v} "
        elif isinstance(v, int) and not isinstance(v, bool):
            args += f"--{k}={v} "

    return args

accelerate_conf = {
    "config_file" : "/content/kohya-trainer/accelerate_config/config.yaml",
    "num_cpu_threads_per_process" : 1,
}

train_conf = {
    "sample_prompts"  : sample_prompt if os.path.exists(sample_prompt) else None,
    "config_file"     : config_file,
    "wandb_api_key"   : wandb_api_key if wandb_api_key else None
}

accelerate_args = train(accelerate_conf)
train_args = train(train_conf)

final_args = f"accelerate launch {accelerate_args} sdxl_train_network.py {train_args}"

os.chdir(repo_dir)
# !{final_args}

from IPython.display import clear_output
clear_output()
print("✅ Training selesai!")

#######################################################

from google.colab import files
finalLora = f"{output_dir}/{project_name}/{project_name}.safetensors"
files.download(finalLora)
print("Download LoRA")
# Out:
# Loading settings from /content/LoRA/config/config_file.toml...
# /content/LoRA/config/config_file
# prepare tokenizers
# Downloading vocab.json: 100% 961k/961k [00:00<00:00, 8.90MB/s]
# Downloading merges.txt: 100% 525k/525k [00:00<00:00, 35.1MB/s]
# Downloading (…)cial_tokens_map.json: 100% 389/389 [00:00<00:00, 2.01MB/s]
# Downloading tokenizer_config.json: 100% 905/905 [00:00<00:00, 4.42MB/s]
# Downloading vocab.json: 100% 862k/862k [00:00<00:00, 3.52MB/s]
# Downloading merges.txt: 100% 525k/525k [00:00<00:00, 36.9MB/s]
# Downloading (…)cial_tokens_map.json: 100% 389/389 [00:00<00:00, 2.29MB/s]
# Downloading tokenizer_config.json: 100% 904/904 [00:00<00:00, 5.66MB/s]
# update token length: 225
# Training with captions.
# loading existing metadata: /content/LoRA/meta_lat.json
# metadata has bucket info, enable bucketing / メタデータにbucket情報があるためbucketを有効にします
# using bucket info in metadata / メタデータ内のbucket情報を使います
# [Dataset 0]
#   batch_size: 4
#   resolution: (1024, 1024)
#   enable_bucket: True
#   min_bucket_reso: None
#   max_bucket_reso: None
#   bucket_reso_steps: None
#   bucket_no_upscale: None
#
#   [Subset 0 of Dataset 0]
#     image_dir: "/content/LoRA/train_data"
#     image_count: 3
#     num_repeats: 2
#     shuffle_caption: True
#     keep_tokens: 0
#     caption_dropout_rate: 0.0
#     caption_dropout_every_n_epoches: 0
#     caption_tag_dropout_rate: 0.0
#     color_aug: False
#     flip_aug: False
#     face_crop_aug_range: None
#     random_crop: False
#     token_warmup_min: 1,
#     token_warmup_step: 0,
#     metadata_file: /content/LoRA/meta_lat.json
#
#
# [Dataset 0]
# loading image sizes.
# 100% 3/3 [00:00<00:00, 76260.07it/s]
# make buckets
# number of images (including repeats) / 各bucketの画像枚数（繰り返し回数を含む）
# bucket 0: resolution (1024, 1024), count: 6
# mean ar error (without repeats): 0.0
# noise_offset is set to 0.0357 / noise_offsetが0.0357に設定されました
# preparing accelerator
# loading model for process 0/1
# load Diffusers pretrained models: stabilityai/stable-diffusion-xl-base-1.0, variant=fp16
# Downloading model_index.json: 100% 609/609 [00:00<00:00, 3.78MB/s]
# Fetching 23 files:   0% 0/23 [00:00<?, ?it/s]
# Downloading (…)cheduler_config.json: 100% 479/479 [00:00<00:00, 2.64MB/s]
# Fetching 23 files:   9% 2/23 [00:01<00:12,  1.63it/s]
# Downloading model.onnx:   0% 0.00/493M [00:00<?, ?B/s]
#
# Downloading tokenizer_2/merges.txt:   0% 0.00/525k [00:00<?, ?B/s]
#
#
# Downloading (…)ncoder_2/config.json: 100% 575/575 [00:00<00:00, 3.35MB/s]
#
#
#
# Downloading (…)_encoder/config.json: 100% 565/565 [00:00<00:00, 3.22MB/s]
#
#
# Downloading tokenizer_2/merges.txt: 100% 525k/525k [00:00<00:00, 4.37MB/s]
#
# Downloading model.onnx:   4% 21.0M/493M [00:00<00:03, 152MB/s]
#
# Downloading (…)cial_tokens_map.json: 100% 460/460 [00:00<00:00, 1.05MB/s]
#
#
# Downloading (…)okenizer_config.json: 100% 725/725 [00:00<00:00, 2.97MB/s]
#
#
# Downloading tokenizer_2/vocab.json:   0% 0.00/1.06M [00:00<?, ?B/s]
# Downloading model.onnx:   9% 41.9M/493M [00:00<00:02, 176MB/s]
#
#
# Downloading unet/config.json: 100% 1.68k/1.68k [00:00<00:00, 7.68MB/s]
#
#
# Downloading tokenizer_2/vocab.json: 100% 1.06M/1.06M [00:00<00:00, 8.24MB/s]
#
# Downloading model.onnx:  13% 62.9M/493M [00:00<00:02, 184MB/s]
#
# Downloading vae/config.json: 100% 642/642 [00:00<00:00, 2.77MB/s]
#
# Downloading model.onnx:  17% 83.9M/493M [00:00<00:02, 175MB/s]
#
# Downloading vae_1_0/config.json: 100% 607/607 [00:00<00:00, 2.45MB/s]
#
# Downloading model.onnx:  23% 115M/493M [00:00<00:02, 166MB/s]
#
# Downloading model.fp16.safetensors:   0% 0.00/246M [00:00<?, ?B/s]
#
#
# Downloading model.fp16.safetensors:   0% 0.00/1.39G [00:00<?, ?B/s]
# Downloading model.onnx:  28% 136M/493M [00:00<00:02, 139MB/s]
#
#
#
# Downloading model.onnx:   0% 0.00/1.04M [00:00<?, ?B/s]
#
# Downloading model.onnx: 100% 1.04M/1.04M [00:00<00:00, 22.1MB/s]
#
#
#
# Downloading model.fp16.safetensors:   2% 21.0M/1.39G [00:00<00:13, 103MB/s]
#
# Downloading model.fp16.safetensors:  13% 31.5M/246M [00:00<00:02, 88.2MB/s]
#
#
# Downloading model.fp16.safetensors:   2% 31.5M/1.39G [00:00<00:15, 85.5MB/s]
# Downloading model.onnx:  32% 157M/493M [00:01<00:02, 118MB/s]
#
#
#
# Downloading model.onnx:   0% 0.00/198M [00:00<?, ?B/s]
#
#
# Downloading model.fp16.safetensors:   3% 41.9M/1.39G [00:00<00:15, 85.6MB/s]
#
#
#
# Downloading model.onnx:   5% 10.5M/198M [00:00<00:02, 85.6MB/s]
#
#
#
#
# Downloading model.onnx:   0% 0.00/7.29M [00:00<?, ?B/s]
#
# Downloading model.fp16.safetensors:  21% 52.4M/246M [00:00<00:02, 78.6MB/s]
# Downloading model.onnx:  36% 178M/493M [00:01<00:03, 102MB/s]
#
#
# Downloading model.fp16.safetensors:   4% 52.4M/1.39G [00:00<00:17, 75.4MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:   0% 0.00/5.14G [00:00<?, ?B/s]
#
#
#
#
# Downloading model.onnx: 100% 7.29M/7.29M [00:00<00:00, 72.5MB/s]
#
#
#
# Downloading model.onnx: 100% 7.29M/7.29M [00:00<00:00, 43.3MB/s]
#
#
# Downloading model.fp16.safetensors:  26% 62.9M/246M [00:00<00:02, 75.5MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:   0% 0.00/167M [00:00<?, ?B/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:   0% 10.5M/5.14G [00:00<01:16, 67.1MB/s]
#
#
# Downloading model.fp16.safetensors:   5% 62.9M/1.39G [00:00<00:19, 68.5MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:   6% 10.5M/167M [00:00<00:02, 75.8MB/s]
#
# Downloading model.fp16.safetensors:  30% 73.4M/246M [00:00<00:02, 71.5MB/s]
#
#
#
# Downloading model.onnx:  16% 31.5M/198M [00:00<00:02, 60.7MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:   0% 21.0M/5.14G [00:00<01:18, 65.2MB/s]
# Downloading model.onnx:  40% 199M/493M [00:01<00:03, 81.4MB/s]
#
#
#
#
#
#
# Downloading model.onnx:   0% 0.00/137M [00:00<?, ?B/s]
#
#
# Downloading model.fp16.safetensors:   5% 73.4M/1.39G [00:01<00:21, 61.4MB/s]
#
#
#
# Downloading model.onnx:  21% 41.9M/198M [00:00<00:02, 65.6MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  13% 21.0M/167M [00:00<00:02, 69.2MB/s]
#
# Downloading model.fp16.safetensors:  34% 83.9M/246M [00:01<00:02, 60.5MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:   1% 31.5M/5.14G [00:00<01:24, 60.5MB/s]
#
#
#
#
#
#
# Downloading model.onnx:   8% 10.5M/137M [00:00<00:01, 83.3MB/s]
# Downloading model.onnx:  43% 210M/493M [00:01<00:03, 72.7MB/s]
#
#
# Downloading model.fp16.safetensors:   6% 83.9M/1.39G [00:01<00:22, 57.3MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  19% 31.5M/167M [00:00<00:02, 65.7MB/s]
#
#
#
# Downloading model.onnx:  26% 52.4M/198M [00:00<00:02, 56.3MB/s]
#
# Downloading model.fp16.safetensors:  38% 94.4M/246M [00:01<00:02, 59.0MB/s]
#
#
#
#
#
#
# Downloading model.onnx:  15% 21.0M/137M [00:00<00:01, 63.3MB/s]
# Downloading model.onnx:  45% 220M/493M [00:02<00:03, 72.2MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  25% 41.9M/167M [00:00<00:01, 66.5MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:   1% 41.9M/5.14G [00:00<01:37, 52.4MB/s]
#
#
#
# Downloading model.onnx:  32% 62.9M/198M [00:01<00:02, 55.6MB/s]
#
#
# Downloading model.fp16.safetensors:   7% 94.4M/1.39G [00:01<00:25, 50.5MB/s]
#
# Downloading model.fp16.safetensors:  43% 105M/246M [00:01<00:02, 59.8MB/s]
#
#
#
#
#
#
# Downloading model.onnx:  23% 31.5M/137M [00:00<00:01, 57.3MB/s]
# Downloading model.onnx:  47% 231M/493M [00:02<00:04, 64.4MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:   1% 52.4M/5.14G [00:00<01:38, 51.5MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  31% 52.4M/167M [00:00<00:02, 55.7MB/s]
#
#
#
# Downloading model.onnx:  37% 73.4M/198M [00:01<00:02, 58.0MB/s]
#
# Downloading model.fp16.safetensors:  47% 115M/246M [00:01<00:02, 54.0MB/s]
#
#
# Downloading model.fp16.safetensors:   8% 105M/1.39G [00:01<00:27, 47.2MB/s]
#
#
#
#
#
#
# Downloading model.onnx:  31% 41.9M/137M [00:00<00:01, 52.2MB/s]
# Downloading model.onnx:  49% 241M/493M [00:02<00:04, 61.1MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  38% 62.9M/167M [00:01<00:02, 50.7MB/s]
#
#
#
# Downloading model.onnx:  42% 83.9M/198M [00:01<00:02, 50.0MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:   1% 62.9M/5.14G [00:01<02:06, 40.0MB/s]
#
#
# Downloading model.fp16.safetensors:   8% 115M/1.39G [00:02<00:27, 46.0MB/s]
# Downloading model.onnx:  51% 252M/493M [00:02<00:04, 48.9MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  44% 73.4M/167M [00:01<00:02, 45.9MB/s]
#
# Downloading model.fp16.safetensors:  51% 126M/246M [00:02<00:02, 40.5MB/s]
#
#
#
#
#
#
# Downloading model.onnx:  38% 52.4M/137M [00:01<00:02, 39.1MB/s]
#
#
#
# Downloading model.onnx:  48% 94.4M/198M [00:01<00:02, 43.9MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:   1% 73.4M/5.14G [00:01<02:05, 40.3MB/s]
#
#
# Downloading model.fp16.safetensors:   9% 126M/1.39G [00:02<00:28, 43.6MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  50% 83.9M/167M [00:01<00:01, 49.7MB/s]
#
# Downloading model.fp16.safetensors:  55% 136M/246M [00:02<00:02, 44.4MB/s]
# Downloading model.onnx:  53% 262M/493M [00:03<00:04, 47.2MB/s]
#
#
#
#
#
#
# Downloading model.onnx:  46% 62.9M/137M [00:01<00:02, 34.8MB/s]
#
#
#
# Downloading model.onnx:  53% 105M/198M [00:02<00:02, 37.6MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:   2% 83.9M/5.14G [00:01<02:24, 34.9MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  56% 94.4M/167M [00:01<00:01, 43.1MB/s]
#
#
# Downloading model.fp16.safetensors:  10% 136M/1.39G [00:02<00:33, 37.2MB/s]
#
# Downloading model.fp16.safetensors:  60% 147M/246M [00:02<00:02, 40.3MB/s]
# Downloading model.onnx:  55% 273M/493M [00:03<00:05, 43.7MB/s]
#
#
#
#
#
#
# Downloading model.onnx:  54% 73.4M/137M [00:01<00:01, 41.1MB/s]
#
#
#
# Downloading model.onnx:  58% 115M/198M [00:02<00:01, 41.7MB/s]
# Downloading model.onnx:  57% 283M/493M [00:03<00:04, 44.9MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  63% 105M/167M [00:02<00:01, 40.6MB/s]
#
#
#
#
#
#
# Downloading model.onnx:  61% 83.9M/137M [00:01<00:01, 40.3MB/s]
#
#
# Downloading model.fp16.safetensors:  11% 147M/1.39G [00:02<00:35, 34.8MB/s]
#
# Downloading model.fp16.safetensors:  64% 157M/246M [00:03<00:02, 36.2MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:   2% 94.4M/5.14G [00:02<02:39, 31.6MB/s]
# Downloading model.onnx:  60% 294M/493M [00:03<00:04, 44.0MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  69% 115M/167M [00:02<00:01, 42.5MB/s]
#
#
# Downloading model.fp16.safetensors:  11% 157M/1.39G [00:03<00:31, 38.8MB/s]
#
#
#
# Downloading model.onnx:  64% 126M/198M [00:02<00:02, 34.7MB/s]
#
# Downloading model.fp16.safetensors:  68% 168M/246M [00:03<00:02, 34.4MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  75% 126M/167M [00:02<00:00, 43.9MB/s]
# Downloading model.onnx:  62% 304M/493M [00:04<00:04, 42.3MB/s]
#
#
#
#
#
#
# Downloading model.onnx:  69% 94.4M/137M [00:02<00:01, 33.0MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:   2% 105M/5.14G [00:02<02:49, 29.8MB/s]
#
#
#
# Downloading model.onnx:  69% 136M/198M [00:03<00:01, 37.1MB/s]
#
#
# Downloading model.fp16.safetensors:  12% 168M/1.39G [00:03<00:38, 32.1MB/s]
#
#
#
# Downloading model.onnx:  74% 147M/198M [00:04<00:03, 16.6MB/s]
# Downloading model.onnx:  64% 315M/493M [00:07<00:19, 9.11MB/s]
#
# Downloading model.fp16.safetensors:  72% 178M/246M [00:07<00:08, 7.87MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:   2% 115M/5.14G [00:06<11:14, 7.45MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  81% 136M/167M [00:06<00:03, 7.81MB/s]
#
#
#
#
#
#
# Downloading model.onnx:  77% 105M/137M [00:06<00:04, 7.48MB/s]
# Downloading model.onnx:  66% 325M/493M [00:08<00:16, 10.5MB/s]
#
#
# Downloading model.fp16.safetensors:  13% 178M/1.39G [00:07<02:36, 7.76MB/s]
#
#
#
# Downloading model.onnx:  79% 157M/198M [00:06<00:04, 8.76MB/s]
#
# Downloading model.fp16.safetensors:  77% 189M/246M [00:07<00:05, 10.1MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  88% 147M/167M [00:06<00:01, 10.5MB/s]
#
#
#
#
#
#
# Downloading model.onnx:  84% 115M/137M [00:06<00:02, 9.76MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:   2% 126M/5.14G [00:06<08:43, 9.56MB/s]
#
#
#
# Downloading model.onnx:  85% 168M/198M [00:07<00:02, 11.5MB/s]
#
#
# Downloading model.fp16.safetensors:  14% 189M/1.39G [00:07<01:57, 10.3MB/s]
# Downloading model.onnx:  68% 336M/493M [00:08<00:11, 13.3MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:   3% 136M/5.14G [00:07<06:57, 12.0MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors:  94% 157M/167M [00:07<00:00, 12.2MB/s]
#
# Downloading model.fp16.safetensors:  81% 199M/246M [00:08<00:04, 11.6MB/s]
# Downloading model.onnx:  70% 346M/493M [00:08<00:09, 15.1MB/s]
#
#
#
#
#
#
# Downloading model.onnx:  92% 126M/137M [00:07<00:00, 11.4MB/s]
#
#
#
# Downloading model.onnx:  90% 178M/198M [00:07<00:01, 13.3MB/s]
#
#
# Downloading model.fp16.safetensors:  14% 199M/1.39G [00:08<01:42, 11.7MB/s]
#
#
#
#
# Downloading (…)del.fp16.safetensors: 100% 167M/167M [00:07<00:00, 15.0MB/s]
#
# Downloading model.fp16.safetensors:  85% 210M/246M [00:08<00:02, 14.6MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:   3% 147M/5.14G [00:07<05:40, 14.6MB/s]
# Downloading (…)del.fp16.safetensors: 100% 167M/167M [00:07<00:00, 21.8MB/s]
#
#
#
#
# Downloading model.onnx:  95% 189M/198M [00:08<00:00, 16.2MB/s]
#
#
#
#
#
#
# Downloading model.onnx: 100% 136M/137M [00:07<00:00, 14.4MB/s]
#
#
# Downloading model.fp16.safetensors:  15% 210M/1.39G [00:08<01:20, 14.7MB/s]
#
# Downloading model.fp16.safetensors:  89% 220M/246M [00:08<00:01, 18.3MB/s]
#
#
#
#
#
# Downloading model.onnx: 100% 137M/137M [00:07<00:00, 18.1MB/s]
#
#
#
#
# Downloading model.onnx: 100% 198M/198M [00:08<00:00, 19.3MB/s]
# Downloading model.onnx:  75% 367M/493M [00:09<00:05, 21.3MB/s]
#
#
# Downloading model.onnx: 100% 198M/198M [00:08<00:00, 23.6MB/s]
#
#
# Downloading model.fp16.safetensors:  94% 231M/246M [00:08<00:00, 22.1MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:   3% 168M/5.14G [00:08<03:44, 22.2MB/s]
# Downloading model.onnx:  77% 377M/493M [00:09<00:04, 26.4MB/s]
#
# Downloading model.fp16.safetensors:  98% 241M/246M [00:09<00:00, 27.8MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:   3% 178M/5.14G [00:08<03:03, 27.0MB/s]
#
#
# Downloading model.fp16.safetensors:  17% 231M/1.39G [00:09<00:52, 22.1MB/s]
# Downloading model.fp16.safetensors: 100% 246M/246M [00:09<00:00, 26.9MB/s]
# Fetching 23 files:  17% 4/23 [00:11<00:59,  3.15s/it]
#
#
# Downloading model.fp16.safetensors:  17% 241M/1.39G [00:09<00:41, 27.9MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:   4% 189M/5.14G [00:08<02:29, 33.1MB/s]
# Downloading model.onnx:  81% 398M/493M [00:09<00:02, 38.5MB/s]
#
#
# Downloading model.fp16.safetensors:  18% 252M/1.39G [00:09<00:33, 34.2MB/s]
# Downloading model.onnx:  83% 409M/493M [00:10<00:01, 47.2MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:   4% 210M/5.14G [00:08<01:43, 47.8MB/s]
#
#
# Downloading model.fp16.safetensors:  19% 262M/1.39G [00:09<00:27, 41.2MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:   4% 220M/5.14G [00:08<01:38, 50.1MB/s]
# Downloading model.onnx:  87% 430M/493M [00:10<00:01, 56.5MB/s]
#
#
# Downloading model.fp16.safetensors:  20% 273M/1.39G [00:09<00:24, 45.9MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:   4% 231M/5.14G [00:09<01:27, 56.1MB/s]
# Downloading model.onnx:  89% 440M/493M [00:10<00:00, 59.0MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:   5% 241M/5.14G [00:09<01:19, 61.8MB/s]
#
#
# Downloading model.fp16.safetensors:  20% 283M/1.39G [00:09<00:23, 47.9MB/s]
# Downloading model.onnx:  92% 451M/493M [00:10<00:00, 61.4MB/s]
#
#
# Downloading model.fp16.safetensors:  21% 294M/1.39G [00:09<00:19, 55.3MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:   5% 252M/5.14G [00:09<01:14, 65.6MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:   5% 262M/5.14G [00:09<01:10, 68.8MB/s]
# Downloading model.onnx:  94% 461M/493M [00:10<00:00, 60.7MB/s]
#
#
# Downloading model.fp16.safetensors:  22% 304M/1.39G [00:10<00:18, 58.6MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:   5% 273M/5.14G [00:09<01:08, 71.0MB/s]
# Downloading model.onnx:  96% 472M/493M [00:10<00:00, 63.8MB/s]
#
#
# Downloading model.fp16.safetensors:  23% 315M/1.39G [00:10<00:17, 62.5MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:   6% 283M/5.14G [00:09<01:05, 74.4MB/s]
#
#
# Downloading model.fp16.safetensors:  23% 325M/1.39G [00:10<00:15, 69.0MB/s]
# Downloading model.onnx:  98% 482M/493M [00:11<00:00, 69.4MB/s]
#
# Downloading (…)del.fp16.safetensors:   0% 0.00/167M [00:00<?, ?B/s]
#
#
# Downloading model.fp16.safetensors:  24% 336M/1.39G [00:10<00:14, 72.4MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:   6% 294M/5.14G [00:09<01:04, 74.5MB/s]
# Downloading model.onnx: 100% 493M/493M [00:11<00:00, 43.5MB/s]
#
#
# Fetching 23 files:  22% 5/23 [00:12<00:47,  2.66s/it]
#
#
# Downloading model.fp16.safetensors:  25% 346M/1.39G [00:10<00:15, 67.5MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:   6% 304M/5.14G [00:10<01:13, 65.5MB/s]
#
# Downloading (…)del.fp16.safetensors:  19% 31.5M/167M [00:00<00:01, 74.5MB/s]
#
#
# Downloading model.fp16.safetensors:  26% 357M/1.39G [00:10<00:16, 63.3MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:   6% 315M/5.14G [00:10<01:14, 64.7MB/s]
#
# Downloading (…)del.fp16.safetensors:  25% 41.9M/167M [00:00<00:01, 75.6MB/s]
#
#
# Downloading model.fp16.safetensors:  26% 367M/1.39G [00:10<00:15, 66.5MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:   6% 325M/5.14G [00:10<01:10, 68.4MB/s]
#
# Downloading (…)del.fp16.safetensors:  38% 62.9M/167M [00:00<00:01, 92.1MB/s]
#
#
# Downloading model.fp16.safetensors:  27% 377M/1.39G [00:11<00:14, 71.6MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:   7% 346M/5.14G [00:10<00:54, 87.2MB/s]
#
#
# Downloading model.fp16.safetensors:  28% 388M/1.39G [00:11<00:13, 76.9MB/s]
#
# Downloading (…)del.fp16.safetensors:  50% 83.9M/167M [00:00<00:00, 96.1MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:   7% 367M/5.14G [00:10<00:49, 97.0MB/s]
#
#
# Downloading model.fp16.safetensors:  29% 409M/1.39G [00:11<00:10, 89.5MB/s]
#
# Downloading (…)del.fp16.safetensors:  63% 105M/167M [00:01<00:00, 103MB/s]
#
#
# Downloading model.fp16.safetensors:  30% 419M/1.39G [00:11<00:10, 92.0MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:   8% 388M/5.14G [00:10<00:47, 101MB/s]
#
#
# Downloading model.fp16.safetensors:  31% 430M/1.39G [00:11<00:10, 91.4MB/s]
#
# Downloading (…)del.fp16.safetensors:  75% 126M/167M [00:01<00:00, 108MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:   8% 409M/5.14G [00:11<00:43, 109MB/s]
#
#
# Downloading model.fp16.safetensors:  32% 440M/1.39G [00:11<00:10, 94.3MB/s]
#
# Downloading (…)del.fp16.safetensors:  88% 147M/167M [00:01<00:00, 109MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:   8% 430M/5.14G [00:11<00:43, 108MB/s]
#
#
# Downloading model.fp16.safetensors:  33% 461M/1.39G [00:11<00:08, 104MB/s]
#
#
# Downloading model.fp16.safetensors:  34% 472M/1.39G [00:12<00:09, 97.7MB/s]
#
# Downloading (…)del.fp16.safetensors: 100% 167M/167M [00:01<00:00, 93.3MB/s]
#
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:   9% 451M/5.14G [00:11<00:50, 91.9MB/s]
#
#
# Downloading model.fp16.safetensors:  35% 493M/1.39G [00:12<00:08, 102MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:   9% 472M/5.14G [00:11<00:45, 101MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  10% 493M/5.14G [00:11<00:38, 120MB/s]
#
#
# Downloading model.fp16.safetensors:  36% 503M/1.39G [00:12<00:11, 74.6MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  10% 514M/5.14G [00:11<00:36, 125MB/s]
#
#
# Downloading model.fp16.safetensors:  38% 524M/1.39G [00:12<00:09, 93.2MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  10% 535M/5.14G [00:12<00:34, 132MB/s]
#
#
# Downloading model.fp16.safetensors:  39% 545M/1.39G [00:12<00:08, 95.8MB/s]
#
#
# Downloading model.fp16.safetensors:  40% 556M/1.39G [00:13<00:10, 83.3MB/s]
#
#
# Downloading model.fp16.safetensors:  41% 566M/1.39G [00:13<00:09, 82.9MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  11% 556M/5.14G [00:12<00:58, 77.8MB/s]
#
#
# Downloading model.fp16.safetensors:  43% 598M/1.39G [00:13<00:06, 120MB/s]
#
#
# Downloading model.fp16.safetensors:  45% 619M/1.39G [00:13<00:05, 133MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  11% 577M/5.14G [00:12<00:58, 78.6MB/s]
#
#
# Downloading model.fp16.safetensors:  46% 640M/1.39G [00:13<00:06, 118MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  11% 587M/5.14G [00:12<00:58, 78.4MB/s]
#
#
# Downloading model.fp16.safetensors:  48% 661M/1.39G [00:13<00:05, 128MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  12% 608M/5.14G [00:13<00:50, 89.1MB/s]
#
#
# Downloading model.fp16.safetensors:  49% 682M/1.39G [00:13<00:05, 127MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  12% 629M/5.14G [00:13<00:44, 101MB/s]
#
#
# Downloading model.fp16.safetensors:  51% 703M/1.39G [00:14<00:05, 137MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  13% 650M/5.14G [00:13<00:40, 111MB/s]
#
#
# Downloading model.fp16.safetensors:  52% 724M/1.39G [00:14<00:04, 147MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  13% 671M/5.14G [00:13<00:36, 122MB/s]
#
#
# Downloading model.fp16.safetensors:  54% 744M/1.39G [00:14<00:04, 146MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  13% 692M/5.14G [00:13<00:32, 135MB/s]
#
#
# Downloading model.fp16.safetensors:  55% 765M/1.39G [00:15<00:15, 40.4MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  14% 713M/5.14G [00:15<01:55, 38.4MB/s]
#
#
# Downloading model.fp16.safetensors:  57% 786M/1.39G [00:15<00:11, 50.9MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  14% 734M/5.14G [00:15<01:28, 49.8MB/s]
#
#
# Downloading model.fp16.safetensors:  58% 807M/1.39G [00:15<00:08, 64.9MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  15% 755M/5.14G [00:15<01:09, 62.7MB/s]
#
#
# Downloading model.fp16.safetensors:  60% 828M/1.39G [00:16<00:07, 78.8MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  15% 776M/5.14G [00:15<00:57, 76.0MB/s]
#
#
# Downloading model.fp16.safetensors:  61% 849M/1.39G [00:16<00:06, 88.1MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  16% 797M/5.14G [00:15<00:50, 86.4MB/s]
#
#
# Downloading model.fp16.safetensors:  63% 870M/1.39G [00:16<00:05, 98.2MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  16% 818M/5.14G [00:17<01:54, 37.6MB/s]
#
#
# Downloading model.fp16.safetensors:  64% 891M/1.39G [00:17<00:12, 39.5MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  16% 828M/5.14G [00:17<01:42, 42.2MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  16% 839M/5.14G [00:17<01:31, 46.8MB/s]
#
#
# Downloading model.fp16.safetensors:  66% 912M/1.39G [00:17<00:10, 47.5MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  17% 849M/5.14G [00:17<01:20, 53.1MB/s]
#
#
# Downloading model.fp16.safetensors:  66% 923M/1.39G [00:18<00:08, 52.1MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  17% 860M/5.14G [00:17<01:11, 59.6MB/s]
#
#
# Downloading model.fp16.safetensors:  67% 933M/1.39G [00:18<00:07, 57.5MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  17% 870M/5.14G [00:17<01:04, 65.7MB/s]
#
#
# Downloading model.fp16.safetensors:  68% 944M/1.39G [00:18<00:07, 62.6MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  17% 881M/5.14G [00:17<00:59, 71.4MB/s]
#
#
# Downloading model.fp16.safetensors:  69% 954M/1.39G [00:18<00:06, 69.3MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  17% 891M/5.14G [00:17<00:54, 77.7MB/s]
#
#
# Downloading model.fp16.safetensors:  69% 965M/1.39G [00:18<00:05, 74.3MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  18% 902M/5.14G [00:17<00:51, 81.5MB/s]
#
#
# Downloading model.fp16.safetensors:  70% 975M/1.39G [00:18<00:05, 80.0MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  18% 923M/5.14G [00:18<00:46, 90.9MB/s]
#
#
# Downloading model.fp16.safetensors:  72% 996M/1.39G [00:18<00:04, 88.0MB/s]
#
#
# Downloading model.fp16.safetensors:  72% 1.01G/1.39G [00:22<00:31, 12.2MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  18% 944M/5.14G [00:22<05:35, 12.5MB/s]
#
#
# Downloading model.fp16.safetensors:  73% 1.02G/1.39G [00:22<00:28, 12.8MB/s]
#
#
# Downloading model.fp16.safetensors:  74% 1.03G/1.39G [00:22<00:21, 16.7MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  19% 965M/5.14G [00:22<03:56, 17.7MB/s]
#
#
# Downloading model.fp16.safetensors:  75% 1.04G/1.39G [00:23<00:17, 19.7MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  19% 975M/5.14G [00:22<03:19, 20.9MB/s]
#
#
# Downloading model.fp16.safetensors:  76% 1.06G/1.39G [00:23<00:10, 31.4MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  19% 996M/5.14G [00:22<02:16, 30.2MB/s]
#
#
# Downloading model.fp16.safetensors:  78% 1.08G/1.39G [00:23<00:06, 46.4MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  20% 1.02G/5.14G [00:22<01:41, 40.6MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  20% 1.04G/5.14G [00:23<01:22, 49.4MB/s]
#
#
# Downloading model.fp16.safetensors:  79% 1.10G/1.39G [00:23<00:05, 51.0MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  21% 1.06G/5.14G [00:23<01:04, 63.1MB/s]
#
#
# Downloading model.fp16.safetensors:  81% 1.12G/1.39G [00:23<00:04, 65.8MB/s]
#
#
# Downloading model.fp16.safetensors:  82% 1.14G/1.39G [00:27<00:17, 13.9MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  21% 1.08G/5.14G [00:27<04:55, 13.7MB/s]
#
#
# Downloading model.fp16.safetensors:  84% 1.16G/1.39G [00:28<00:11, 19.3MB/s]
#
#
# Downloading model.fp16.safetensors:  85% 1.18G/1.39G [00:28<00:07, 26.8MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  21% 1.10G/5.14G [00:27<03:34, 18.8MB/s]
#
#
# Downloading model.fp16.safetensors:  87% 1.21G/1.39G [00:28<00:05, 36.0MB/s]
#
#
# Downloading model.fp16.safetensors:  88% 1.23G/1.39G [00:28<00:03, 47.9MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  22% 1.12G/5.14G [00:27<02:39, 25.1MB/s]
#
#
# Downloading model.fp16.safetensors:  90% 1.25G/1.39G [00:28<00:02, 55.1MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  22% 1.14G/5.14G [00:28<02:05, 31.8MB/s]
#
#
# Downloading model.fp16.safetensors:  91% 1.27G/1.39G [00:28<00:01, 66.0MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  23% 1.16G/5.14G [00:28<01:36, 41.1MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  23% 1.18G/5.14G [00:28<01:14, 52.7MB/s]
#
#
# Downloading model.fp16.safetensors:  93% 1.29G/1.39G [00:28<00:01, 78.0MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  23% 1.21G/5.14G [00:28<00:58, 66.9MB/s]
#
#
# Downloading model.fp16.safetensors:  94% 1.31G/1.39G [00:29<00:00, 91.7MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  24% 1.23G/5.14G [00:28<00:47, 81.9MB/s]
#
#
# Downloading model.fp16.safetensors:  96% 1.33G/1.39G [00:29<00:00, 101MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  24% 1.25G/5.14G [00:28<00:42, 90.4MB/s]
#
#
# Downloading model.fp16.safetensors:  97% 1.35G/1.39G [00:29<00:00, 112MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  25% 1.27G/5.14G [00:28<00:39, 99.1MB/s]
#
#
# Downloading model.fp16.safetensors:  99% 1.37G/1.39G [00:29<00:00, 114MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  25% 1.29G/5.14G [00:29<00:35, 107MB/s]
#
#
# Downloading model.fp16.safetensors: 100% 1.39G/1.39G [00:29<00:00, 46.7MB/s]
# Fetching 23 files:  30% 7/23 [00:31<01:33,  5.83s/it]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  26% 1.31G/5.14G [00:29<00:32, 117MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  26% 1.34G/5.14G [00:29<00:26, 141MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  27% 1.36G/5.14G [00:29<00:25, 149MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  27% 1.38G/5.14G [00:29<00:23, 162MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  28% 1.42G/5.14G [00:29<00:20, 180MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  28% 1.45G/5.14G [00:29<00:18, 196MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  29% 1.48G/5.14G [00:29<00:17, 211MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  29% 1.51G/5.14G [00:30<00:15, 227MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  30% 1.54G/5.14G [00:30<00:15, 235MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  31% 1.57G/5.14G [00:30<00:15, 230MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  31% 1.60G/5.14G [00:30<00:15, 235MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  32% 1.64G/5.14G [00:30<00:14, 239MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  32% 1.67G/5.14G [00:30<00:13, 249MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  33% 1.70G/5.14G [00:30<00:13, 248MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  34% 1.73G/5.14G [00:30<00:13, 249MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  34% 1.76G/5.14G [00:31<00:13, 250MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  35% 1.79G/5.14G [00:31<00:13, 254MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  36% 1.82G/5.14G [00:31<00:13, 246MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  36% 1.86G/5.14G [00:31<00:13, 243MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  37% 1.89G/5.14G [00:31<00:13, 247MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  37% 1.92G/5.14G [00:31<00:12, 258MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  38% 1.95G/5.14G [00:31<00:12, 257MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  39% 1.98G/5.14G [00:31<00:12, 257MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  39% 2.01G/5.14G [00:32<00:12, 257MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  40% 2.04G/5.14G [00:32<00:11, 266MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  40% 2.08G/5.14G [00:32<00:12, 236MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  41% 2.11G/5.14G [00:32<00:14, 216MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  42% 2.14G/5.14G [00:32<00:13, 229MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  42% 2.17G/5.14G [00:32<00:13, 225MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  43% 2.20G/5.14G [00:32<00:12, 233MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  43% 2.23G/5.14G [00:33<00:12, 226MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  44% 2.26G/5.14G [00:33<00:13, 205MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  45% 2.30G/5.14G [00:33<00:17, 166MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  45% 2.32G/5.14G [00:33<00:16, 172MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  46% 2.34G/5.14G [00:33<00:15, 180MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  46% 2.36G/5.14G [00:33<00:14, 185MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  47% 2.39G/5.14G [00:33<00:14, 196MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  47% 2.41G/5.14G [00:34<00:13, 197MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  47% 2.43G/5.14G [00:34<00:13, 196MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  48% 2.46G/5.14G [00:34<00:12, 211MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  49% 2.50G/5.14G [00:34<00:12, 218MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  49% 2.53G/5.14G [00:34<00:12, 201MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  50% 2.55G/5.14G [00:34<00:13, 193MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  50% 2.57G/5.14G [00:34<00:13, 185MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  50% 2.59G/5.14G [00:35<00:14, 177MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  51% 2.61G/5.14G [00:36<00:57, 43.9MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  51% 2.63G/5.14G [00:36<00:48, 52.1MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  52% 2.66G/5.14G [00:36<00:33, 73.7MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  52% 2.69G/5.14G [00:36<00:24, 100MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  53% 2.72G/5.14G [00:37<00:24, 98.6MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  53% 2.74G/5.14G [00:37<00:21, 114MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  54% 2.77G/5.14G [00:37<00:16, 144MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  55% 2.80G/5.14G [00:37<00:13, 174MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  55% 2.83G/5.14G [00:37<00:12, 183MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  56% 2.86G/5.14G [00:37<00:11, 190MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  56% 2.89G/5.14G [00:37<00:10, 205MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  57% 2.93G/5.14G [00:38<00:10, 208MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  58% 2.96G/5.14G [00:38<00:10, 216MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  58% 2.99G/5.14G [00:38<00:09, 225MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  59% 3.02G/5.14G [00:38<00:09, 227MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  59% 3.05G/5.14G [00:38<00:08, 235MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  60% 3.08G/5.14G [00:38<00:08, 243MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  61% 3.11G/5.14G [00:38<00:08, 237MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  61% 3.15G/5.14G [00:38<00:08, 238MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  62% 3.18G/5.14G [00:39<00:08, 241MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  62% 3.21G/5.14G [00:39<00:08, 239MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  63% 3.24G/5.14G [00:39<00:07, 243MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  64% 3.27G/5.14G [00:39<00:07, 246MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  64% 3.30G/5.14G [00:39<00:07, 249MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  65% 3.33G/5.14G [00:39<00:07, 237MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  66% 3.37G/5.14G [00:39<00:07, 245MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  66% 3.40G/5.14G [00:39<00:07, 246MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  67% 3.43G/5.14G [00:40<00:06, 249MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  67% 3.46G/5.14G [00:40<00:10, 164MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  68% 3.49G/5.14G [00:40<00:08, 184MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  69% 3.52G/5.14G [00:40<00:07, 208MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  69% 3.55G/5.14G [00:40<00:07, 216MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  70% 3.59G/5.14G [00:40<00:07, 212MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  70% 3.62G/5.14G [00:41<00:06, 222MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  71% 3.65G/5.14G [00:42<00:18, 80.8MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  71% 3.67G/5.14G [00:42<00:15, 92.2MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  72% 3.69G/5.14G [00:42<00:15, 93.9MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  72% 3.72G/5.14G [00:42<00:12, 117MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  73% 3.75G/5.14G [00:42<00:09, 143MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  74% 3.79G/5.14G [00:42<00:08, 160MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  74% 3.81G/5.14G [00:42<00:08, 164MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  75% 3.83G/5.14G [00:43<00:08, 162MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  75% 3.86G/5.14G [00:43<00:07, 181MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  76% 3.88G/5.14G [00:44<00:22, 56.2MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  76% 3.90G/5.14G [00:45<00:28, 43.1MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  76% 3.92G/5.14G [00:45<00:22, 54.6MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  77% 3.94G/5.14G [00:45<00:19, 61.7MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  77% 3.96G/5.14G [00:47<00:43, 27.2MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  78% 3.98G/5.14G [00:47<00:32, 35.9MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  78% 4.01G/5.14G [00:48<00:43, 25.9MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  78% 4.03G/5.14G [00:48<00:32, 34.3MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  79% 4.05G/5.14G [00:49<00:24, 44.9MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  79% 4.08G/5.14G [00:49<00:16, 65.2MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  80% 4.11G/5.14G [00:49<00:11, 87.8MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  81% 4.14G/5.14G [00:49<00:09, 110MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  81% 4.17G/5.14G [00:49<00:07, 133MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  82% 4.20G/5.14G [00:49<00:05, 155MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  82% 4.24G/5.14G [00:49<00:05, 174MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  83% 4.27G/5.14G [00:49<00:04, 185MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  84% 4.30G/5.14G [00:50<00:04, 199MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  84% 4.33G/5.14G [00:50<00:03, 209MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  85% 4.36G/5.14G [00:50<00:03, 225MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  86% 4.39G/5.14G [00:50<00:03, 236MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  86% 4.42G/5.14G [00:50<00:03, 224MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  87% 4.46G/5.14G [00:50<00:02, 235MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  87% 4.49G/5.14G [00:50<00:02, 247MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  88% 4.52G/5.14G [00:51<00:02, 235MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  89% 4.55G/5.14G [00:51<00:02, 238MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  89% 4.58G/5.14G [00:51<00:02, 242MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  90% 4.61G/5.14G [00:53<00:10, 49.9MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  90% 4.63G/5.14G [00:53<00:08, 59.5MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  91% 4.67G/5.14G [00:53<00:05, 80.2MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  91% 4.70G/5.14G [00:53<00:04, 104MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  92% 4.73G/5.14G [00:53<00:03, 123MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  93% 4.76G/5.14G [00:53<00:02, 142MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  93% 4.79G/5.14G [00:53<00:02, 161MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  94% 4.82G/5.14G [00:53<00:01, 178MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  95% 4.85G/5.14G [00:54<00:01, 187MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  95% 4.89G/5.14G [00:54<00:01, 200MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  96% 4.92G/5.14G [00:54<00:01, 215MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  96% 4.95G/5.14G [00:54<00:00, 223MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  97% 4.98G/5.14G [00:54<00:00, 232MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  98% 5.01G/5.14G [00:54<00:00, 237MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  98% 5.04G/5.14G [00:54<00:00, 235MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  99% 5.08G/5.14G [00:55<00:00, 238MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors:  99% 5.11G/5.14G [00:55<00:00, 238MB/s]
#
#
#
#
#
# Downloading (…)del.fp16.safetensors: 100% 5.14G/5.14G [00:55<00:00, 92.9MB/s]
# Fetching 23 files: 100% 23/23 [00:57<00:00,  2.52s/it]
# The config attributes {'add_watermarker': None} were passed to StableDiffusionXLPipeline, but are not expected and will be ignored. Please verify your model_index.json configuration file.
# Keyword arguments {'add_watermarker': None} are not expected by StableDiffusionXLPipeline and will be ignored.
# The config attributes {'force_upcast': True} were passed to AutoencoderKL, but are not expected and will be ignored. Please verify your config.json configuration file.
# U-Net converted to original U-Net
# load VAE: /content/vae/sdxl_vae.safetensors
# additional VAE loaded
# Enable SDPA for U-Net
# import network module: networks.lora
# create LoRA network. base dim (rank): 32, alpha: 16
# neuron dropout: p=None, rank dropout: p=None, module dropout: p=None
# create LoRA for Text Encoder 1:
# create LoRA for Text Encoder 2:
# create LoRA for Text Encoder: 264 modules.
# create LoRA for U-Net: 722 modules.
# enable LoRA for U-Net
# prepare optimizer, data loader etc.
# use Adafactor optimizer | {'scale_parameter': False, 'relative_step': False, 'warmup_init': False}
# override steps. steps for 10 epochs is / 指定エポックまでのステップ数: 20
# running training / 学習開始
#   num train images * repeats / 学習画像の数×繰り返し回数: 6
#   num reg images / 正則化画像の数: 0
#   num batches per epoch / 1epochのバッチ数: 2
#   num epochs / epoch数: 10
#   batch size per device / バッチサイズ: 4
#   gradient accumulation steps / 勾配を合計するステップ数 = 1
#   total optimization steps / 学習ステップ数: 20
# steps:   0% 0/20 [00:00<?, ?it/s]
# epoch 1/10
# steps:  10% 2/20 [00:12<01:50,  6.13s/it, loss=0.0701]
# saving checkpoint: /content/LoRA/output/sdxl_lora/sdxl_lora-000001.safetensors
#
# epoch 2/10
# steps:  20% 4/20 [00:26<01:45,  6.61s/it, loss=0.0993]
# saving checkpoint: /content/LoRA/output/sdxl_lora/sdxl_lora-000002.safetensors
#
# epoch 3/10
# steps:  30% 6/20 [00:36<01:25,  6.13s/it, loss=0.0839]
# saving checkpoint: /content/LoRA/output/sdxl_lora/sdxl_lora-000003.safetensors
#
# epoch 4/10
# steps:  40% 8/20 [00:47<01:11,  5.95s/it, loss=0.176]
# saving checkpoint: /content/LoRA/output/sdxl_lora/sdxl_lora-000004.safetensors
#
# epoch 5/10
# steps:  50% 10/20 [01:02<01:02,  6.25s/it, loss=0.0769]
# saving checkpoint: /content/LoRA/output/sdxl_lora/sdxl_lora-000005.safetensors
#
# epoch 6/10
# steps:  60% 12/20 [01:14<00:49,  6.17s/it, loss=0.108]
# saving checkpoint: /content/LoRA/output/sdxl_lora/sdxl_lora-000006.safetensors
#
# epoch 7/10
# steps:  70% 14/20 [01:30<00:38,  6.44s/it, loss=0.0316]
# saving checkpoint: /content/LoRA/output/sdxl_lora/sdxl_lora-000007.safetensors
#
# epoch 8/10
